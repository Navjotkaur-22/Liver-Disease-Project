# %%
# !pip install streamlit pandas numpy joblib scikit-learn xgboost
# Out:
# Collecting streamlit
#   Downloading streamlit-1.50.0-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: pandas in c:\users\hp\anaconda3\envs\datascience_env\lib\site-packages (2.3.2)
# Requirement already satisfied: numpy in c:\users\hp\anaconda3\envs\datascience_env\lib\site-packages (1.26.4)
# Requirement already satisfied: joblib in c:\users\hp\anaconda3\envs\datascience_env\lib\site-packages (1.5.2)
# Requirement already satisfied: scikit-learn in c:\users\hp\anaconda3\envs\datascience_env\lib\site-packages (1.5.1)
# Requirement already satisfied: xgboost in c:\users\hp\anaconda3\envs\datascience_env\lib\site-packages (2.1.4)
# Collecting altair!=5.4.0,!=5.4.1,<6,>=4.0 (from streamlit)
#   Downloading altair-5.5.0-py3-none-any.whl.metadata (11 kB)
# Collecting blinker<2,>=1.5.0 (from streamlit)
#   Downloading blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting cachetools<7,>=4.0 (from streamlit)
#   Downloading cachetools-6.2.1-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: click<9,>=7.0 in c:\users\hp\anaconda3\envs\datascience_env\lib\site-packages (from streamlit) (8.1.8)
# Requirement already satisfied: packaging<26,>=20 in c:\users\hp\anaconda3\envs\datascience_env\lib\site-packages (from streamlit) (25.0)
# Requirement already satisfied: pillow<12,>=7.1.0 in c:\users\hp\anaconda3\envs\datascience_env\lib\site-packages (from streamlit) (11.1.0)
# Requirement already satisfied: protobuf<7,>=3.20 in c:\users\hp\anaconda3\envs\datascience_env\lib\site-packages (from streamlit) (5.29.3)
# Collecting pyarrow>=7.0 (from streamlit)
#   Downloading pyarrow-21.0.0-cp39-cp39-win_amd64.whl.metadata (3.4 kB)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\hp\anaconda3\envs\datascience_env\lib\site-packages (from streamlit) (2.32.5)
# Collecting tenacity<10,>=8.1.0 (from streamlit)
#   Downloading tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Collecting toml<2,>=0.10.1 (from streamlit)
#   Downloading toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in c:\users\hp\anaconda3\envs\datascience_env\lib\site-packages (from streamlit) (4.15.0)
# Collecting watchdog<7,>=2.1.5 (from streamlit)
#   Downloading watchdog-6.0.0-py3-none-win_amd64.whl.metadata (44 kB)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit)
#   Downloading gitpython-3.1.45-py3-none-any.whl.metadata (13 kB)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in c:\users\hp\anaconda3\envs\datascience_env\lib\site-packages (from streamlit) (6.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hp\anaconda3\envs\datascience_env\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\anaconda3\envs\datascience_env\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hp\anaconda3\envs\datascience_env\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: jinja2 in c:\users\hp\anaconda3\envs\datascience_env\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\hp\anaconda3\envs\datascience_env\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (4.25.0)
# Collecting narwhals>=1.14.2 (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit)
#   Downloading narwhals-2.10.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: colorama in c:\users\hp\anaconda3\envs\datascience_env\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\hp\anaconda3\envs\datascience_env\lib\site-packages (from requests<3,>=2.27->streamlit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\anaconda3\envs\datascience_env\lib\site-packages (from requests<3,>=2.27->streamlit) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp\anaconda3\envs\datascience_env\lib\site-packages (from requests<3,>=2.27->streamlit) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\anaconda3\envs\datascience_env\lib\site-packages (from requests<3,>=2.27->streamlit) (2025.8.3)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\hp\anaconda3\envs\datascience_env\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\hp\anaconda3\envs\datascience_env\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hp\anaconda3\envs\datascience_env\lib\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\hp\anaconda3\envs\datascience_env\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\hp\anaconda3\envs\datascience_env\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\hp\anaconda3\envs\datascience_env\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\hp\anaconda3\envs\datascience_env\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.22.3)
# Requirement already satisfied: six>=1.5 in c:\users\hp\anaconda3\envs\datascience_env\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading streamlit-1.50.0-py3-none-any.whl (10.1 MB)
#    ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/10.1 MB 2.8 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.3/10.1 MB 4.2 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.6/10.1 MB 4.9 MB/s eta 0:00:02
#    ---------------- ----------------------- 4.2/10.1 MB 5.7 MB/s eta 0:00:02
#    ------------------------ --------------- 6.3/10.1 MB 6.5 MB/s eta 0:00:01
#    -------------------------------- ------- 8.1/10.1 MB 7.0 MB/s eta 0:00:01
#    ---------------------------------------  10.0/10.1 MB 7.2 MB/s eta 0:00:01
#    ---------------------------------------- 10.1/10.1 MB 7.0 MB/s  0:00:01
# Downloading altair-5.5.0-py3-none-any.whl (731 kB)
#    ---------------------------------------- 0.0/731.2 kB ? eta -:--:--
#    ---------------------------------------- 731.2/731.2 kB 7.4 MB/s  0:00:00
# Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Downloading cachetools-6.2.1-py3-none-any.whl (11 kB)
# Downloading gitpython-3.1.45-py3-none-any.whl (208 kB)
# Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
# Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#    ---------------------------------------- 0.0/6.9 MB ? eta -:--:--
#    ------------ --------------------------- 2.1/6.9 MB 10.7 MB/s eta 0:00:01
#    ---------------------- ----------------- 3.9/6.9 MB 9.4 MB/s eta 0:00:01
#    --------------------------------- ------ 5.8/6.9 MB 9.5 MB/s eta 0:00:01
#    ---------------------------------------- 6.9/6.9 MB 9.0 MB/s  0:00:00
# Downloading smmap-5.0.2-py3-none-any.whl (24 kB)
# Downloading tenacity-9.1.2-py3-none-any.whl (28 kB)
# Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Downloading watchdog-6.0.0-py3-none-win_amd64.whl (79 kB)
# Downloading narwhals-2.10.0-py3-none-any.whl (418 kB)
# Downloading pyarrow-21.0.0-cp39-cp39-win_amd64.whl (26.2 MB)
#    ---------------------------------------- 0.0/26.2 MB ? eta -:--:--
#    --- ------------------------------------ 2.1/26.2 MB 10.7 MB/s eta 0:00:03
#    ---- ----------------------------------- 3.1/26.2 MB 10.3 MB/s eta 0:00:03
#    ------ --------------------------------- 4.2/26.2 MB 6.6 MB/s eta 0:00:04
#    ------- -------------------------------- 4.7/26.2 MB 6.8 MB/s eta 0:00:04
#    ------- -------------------------------- 4.7/26.2 MB 6.8 MB/s eta 0:00:04
#    --------- ------------------------------ 6.3/26.2 MB 4.9 MB/s eta 0:00:05
#    ----------- ---------------------------- 7.6/26.2 MB 5.2 MB/s eta 0:00:04
#    ------------- -------------------------- 9.2/26.2 MB 5.5 MB/s eta 0:00:04
#    ---------------- ----------------------- 10.7/26.2 MB 5.7 MB/s eta 0:00:03
#    ------------------- -------------------- 12.8/26.2 MB 6.1 MB/s eta 0:00:03
#    ---------------------- ----------------- 14.7/26.2 MB 6.4 MB/s eta 0:00:02
#    ------------------------- -------------- 16.5/26.2 MB 6.6 MB/s eta 0:00:02
#    --------------------------- ------------ 18.4/26.2 MB 6.8 MB/s eta 0:00:02
#    ------------------------------ --------- 20.2/26.2 MB 6.9 MB/s eta 0:00:01
#    -------------------------------- ------- 21.2/26.2 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 22.8/26.2 MB 6.8 MB/s eta 0:00:01
#    ------------------------------------- -- 24.6/26.2 MB 6.9 MB/s eta 0:00:01
#    ---------------------------------------  26.2/26.2 MB 7.0 MB/s eta 0:00:01
#    ---------------------------------------- 26.2/26.2 MB 7.0 MB/s  0:00:03
# Installing collected packages: watchdog, toml, tenacity, smmap, pyarrow, narwhals, cachetools, blinker, pydeck, gitdb, gitpython, altair, streamlit
#
#    --- ------------------------------------  1/13 [toml]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    --------------- ------------------------  5/13 [narwhals]
#    --------------- ------------------------  5/13 [narwhals]
#    --------------- ------------------------  5/13 [narwhals]
#    --------------- ------------------------  5/13 [narwhals]
#    ------------------ ---------------------  6/13 [cachetools]
#    ------------------------ ---------------  8/13 [pydeck]
#    --------------------------- ------------  9/13 [gitdb]
#    ------------------------------ --------- 10/13 [gitpython]
#    --------------------------------- ------ 11/13 [altair]
#    --------------------------------- ------ 11/13 [altair]
#    --------------------------------- ------ 11/13 [altair]
#    ------------------------------------ --- 12/13 [streamlit]
#    ------------------------------------ --- 12/13 [streamlit]
#    ------------------------------------ --- 12/13 [streamlit]
#    ------------------------------------ --- 12/13 [streamlit]
#    ------------------------------------ --- 12/13 [streamlit]
#    ------------------------------------ --- 12/13 [streamlit]
#    ------------------------------------ --- 12/13 [streamlit]
#    ------------------------------------ --- 12/13 [streamlit]
#    ------------------------------------ --- 12/13 [streamlit]
#    ---------------------------------------- 13/13 [streamlit]
#
# Successfully installed altair-5.5.0 blinker-1.9.0 cachetools-6.2.1 gitdb-4.0.12 gitpython-3.1.45 narwhals-2.10.0 pyarrow-21.0.0 pydeck-0.9.1 smmap-5.0.2 streamlit-1.50.0 tenacity-9.1.2 toml-0.10.2 watchdog-6.0.0

# %%
code = r"""
code = r"""
import streamlit as st
import pandas as pd
import numpy as np
import joblib, os

st.set_page_config(page_title="Liver Disease Prediction", page_icon="🩺")
st.title("🩺 Liver Disease Prediction App")
st.write("KNN / XGBoost models ke saath manual input & CSV upload. Headers auto-fix + NaN-safe preprocessing.")

FEATURES = [
    "Age","Gender","Total_Bilirubin","Direct_Bilirubin","Alkaline_Phosphotase",
    "Alamine_Aminotransferase","Aspartate_Aminotransferase","Total_Protiens",
    "Albumin","Albumin_and_Globulin_Ratio"
]

@st.cache_resource
def load_models():
    m = {}
    if os.path.exists("best_knn_liver_model.joblib"): m["KNN"]=joblib.load("best_knn_liver_model.joblib")
    if os.path.exists("best_xgb_liver_model.joblib"): m["XGBoost"]=joblib.load("best_xgb_liver_model.joblib")
    if os.path.exists("scaler_for_knn.joblib"):       m["SCALER"]=joblib.load("scaler_for_knn.joblib")
    return m

MODELS = load_models()
AVAILABLE = [m for m in ["KNN","XGBoost"] if m in MODELS]
if not AVAILABLE:
    st.error("Model files nahi mile. Place best_knn_liver_model.joblib / best_xgb_liver_model.joblib (and scaler_for_knn.joblib for KNN).")
    st.stop()

model_choice = st.radio("Select model", AVAILABLE, horizontal=True)
st.caption("Required columns: " + ", ".join(FEATURES))

def normalize_headers(df: pd.DataFrame) -> pd.DataFrame:
    def norm(s): return str(s).strip().lower().replace(" ","_").replace("-","_").replace("/","_")
    mapping = {
        "age":"Age","gender":"Gender","total_bilirubin":"Total_Bilirubin","direct_bilirubin":"Direct_Bilirubin",
        "alkaline_phosphotase":"Alkaline_Phosphotase","alkaline_phosphatase":"Alkaline_Phosphotase",
        "alamine_aminotransferase":"Alamine_Aminotransferase","aspartate_aminotransferase":"Aspartate_Aminotransferase",
        "total_proteins":"Total_Protiens","total_protiens":"Total_Protiens",
        "albumin":"Albumin","albumin_and_globulin_ratio":"Albumin_and_Globulin_Ratio","agr":"Albumin_and_Globulin_Ratio","a_g_ratio":"Albumin_and_Globulin_Ratio"
    }
    return df.rename(columns={c: mapping.get(norm(c), c) for c in df.columns})

def preprocess(df_raw: pd.DataFrame) -> pd.DataFrame:
    df = df_raw.copy()
    df.columns = [c.strip() for c in df.columns]
    df = normalize_headers(df)

    missing = [c for c in FEATURES if c not in df.columns]
    if missing:
        # index-like extra col drop
        if df.shape[1] == len(FEATURES) + 1:
            first = df.columns[0]
            if str(first).lower().startswith("unnamed") or str(first).lower() in ("index",""):
                df = df.drop(columns=[first])
        if df.shape[1] == len(FEATURES):
            df.columns = FEATURES
        else:
            raise ValueError(f"Missing required columns: {missing}")

    if df["Gender"].dtype == object:
        df["Gender"] = df["Gender"].astype(str).str.strip().map({"Male":1,"Male ":1,"M":1,"male":1,"Female":0,"female":0,"F":0})

    X = df[FEATURES].copy()
    for col in FEATURES:
        if col != "Gender":
            X[col] = pd.to_numeric(X[col], errors="coerce")
    num_cols = X.select_dtypes(include=[np.number]).columns
    for c in num_cols:
        X[c] = X[c].fillna(X[c].median())
    X = X.fillna(X.median(numeric_only=True))

    if model_choice == "KNN" and "SCALER" in MODELS:
        X[num_cols] = MODELS["SCALER"].transform(X[num_cols])

    return X

def smart_read_csv(uploaded_file):
    tries = []
    def normal(f):   return pd.read_csv(f)
    def autosep(f):  return pd.read_csv(f, sep=None, engine="python")
    def headerless(f):
        df = pd.read_csv(f, header=None)
        if df.shape[1] == len(FEATURES) + 1:
            df = df.drop(columns=df.columns[0])
        if df.shape[1] != len(FEATURES):
            raise ValueError(f"Headerless CSV must have {len(FEATURES)} cols, found {df.shape[1]}")
        df.columns = FEATURES
        return df
    for reader in (normal, autosep, headerless):
        uploaded_file.seek(0)
        try:
            return reader(uploaded_file)
        except Exception as e:
            tries.append(str(e))
    raise ValueError("; ".join(tries))

tab1, tab2 = st.tabs(["🔢 Manual Input", "📄 CSV Upload"])

with tab1:
    st.subheader("Enter patient features")
    c1, c2 = st.columns(2)
    Age = c1.number_input("Age", 0, 120, 45)
    Gender = c2.selectbox("Gender", ["Male","Female"])
    Total_Bilirubin = c1.number_input("Total_Bilirubin", 0.0, 999.0, 1.0)
    Direct_Bilirubin = c2.number_input("Direct_Bilirubin", 0.0, 999.0, 0.3)
    Alkaline_Phosphotase = c1.number_input("Alkaline_Phosphotase", 0, 10000, 200)
    Alamine_Aminotransferase = c2.number_input("Alamine_Aminotransferase", 0, 10000, 30)
    Aspartate_Aminotransferase = c1.number_input("Aspartate_Aminotransferase", 0, 10000, 35)
    Total_Protiens = c2.number_input("Total_Protiens", 0.0, 999.0, 6.5)
    Albumin = c1.number_input("Albumin", 0.0, 999.0, 3.5)
    Albumin_and_Globulin_Ratio = c2.number_input("Albumin_and_Globulin_Ratio", 0.0, 999.0, 1.0)

    if st.button("Predict", use_container_width=True):
        row = {
            "Age": Age, "Gender": 1 if Gender=="Male" else 0,
            "Total_Bilirubin": Total_Bilirubin, "Direct_Bilirubin": Direct_Bilirubin,
            "Alkaline_Phosphotase": Alkaline_Phosphotase, "Alamine_Aminotransferase": Alamine_Aminotransferase,
            "Aspartate_Aminotransferase": Aspartate_Aminotransferase, "Total_Protiens": Total_Protiens,
            "Albumin": Albumin, "Albumin_and_Globulin_Ratio": Albumin_and_Globulin_Ratio
        }
        try:
            X = preprocess(pd.DataFrame([row]))
            model = MODELS[model_choice]
            pred = int(model.predict(X)[0])
            st.success(f"Prediction: **{'Liver Disease' if pred==1 else 'No Disease'}**")
            if hasattr(model, 'predict_proba'):
                st.write(f"Probability (class 1): **{model.predict_proba(X)[0,1]:.2f}**")
        except Exception as e:
            st.error(f"Error during prediction: {e}")

with tab2:
    st.subheader("Upload CSV (auto-fix headers/index)")
    debug = st.checkbox("Show debug info", value=True)
    file = st.file_uploader("Select CSV file", type=["csv"])
    if file is not None:
        try:
            raw = smart_read_csv(file)
            if debug:
                st.write("🔹 Raw detected columns:", list(raw.columns))
                st.write("🔹 Raw head:", raw.head())
            X = preprocess(raw)
            if debug:
                st.write("🔹 Final dtypes:", {k:str(v) for k,v in X.dtypes.items()})
                st.write("🔹 NaN counts:", X.isna().sum().to_dict())
            model = MODELS[model_choice]
            preds = model.predict(X)
            out = raw.copy()
            out["prediction"] = preds
            if hasattr(model, "predict_proba"):
                out["proba_1"] = model.predict_proba(X)[:,1]
            st.write("Sample predictions:", out.head())
            st.download_button(label="Download predictions CSV",
                               data=out.to_csv(index=False).encode("utf-8"),
                               file_name="liver_predictions.csv",
                               mime="text/csv")
        except Exception as e:
            st.error(f"Failed to score CSV: {e}")

st.info("Gender: Male=1, Female=0. Numeric NaNs -> median. KNN uses saved scaler.")
"""
with open("app.py","w",encoding="utf-8") as f:
    f.write(code)
print("✅ app.py overwritten cleanly.")

"""
with open("app.py", "w", encoding="utf-8") as f:
    f.write(code)
print("✅ app.py overwritten cleanly.")
# Out:
# 2025-10-28 13:57:05.568 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:05.568 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:05.753
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\HP\anaconda3\envs\datascience_env\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-10-28 13:57:05.753 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:05.753 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:05.757 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:05.757 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:05.757 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:05.762 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:05.763 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:05.763 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:05.765 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:06.278 Thread 'Thread-5': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:06.280 Thread 'Thread-5': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:06.280 Thread 'Thread-5': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.103 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.105 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.105 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.107 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.107 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.107 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.109 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.110 Session state does not function when running a script without `streamlit run`
# 2025-10-28 13:57:17.110 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.110 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.112 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.113 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.113 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.114 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.116 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.118 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.123 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.125 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.129 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.131 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.133 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.140 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.140 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.144 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.145 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.148 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.148 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.150 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.150 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.153 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.155 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.157 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.160 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.162 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.164 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.164 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.166 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.168 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.169 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.169 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.170 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.172 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.172 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.174 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.174 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.176 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.176 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.176 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.178 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.178 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.180 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.180 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.180 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.182 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.183 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.183 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.185 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.185 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.187 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.188 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.188 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.190 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.191 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.191 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.193 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.193 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.193 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.195 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.195 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.195 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.197 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.197 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.197 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.201 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.205 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.205 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.205 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.208 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.210 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.210 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.212 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.213 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.213 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.213 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.217 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.217 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.217 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.219 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.219 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.221 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.221 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.224 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.226 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.226 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.226 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.226 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.226 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.226 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.226 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.231 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.231 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.233 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.233 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.233 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.233 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.238 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.238 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.238 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.241 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.241 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.241 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.243 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.244 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.245 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.246 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.246 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-28 13:57:17.246 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ✅ app.py overwritten cleanly.
